# %% [markdown]
# <a href="https://colab.research.google.com/github/trisha123789/AIR_PASSENGER_TIME_SERIES_LSTM/blob/main/AIR_PASSENGER_TIME_SERIES_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM

# %%
df = pd.read_csv('')
